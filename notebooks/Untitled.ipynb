# %%
import pandas as pd

# %%
df = pd.read_csv("../data/survey_data_updated.csv")

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           2                     I am a developer by profession
# 1           3                     I am a developer by profession
# 2          10                     I am a developer by profession
# 3          11  I used to be a developer by profession, but no...
# 4          12                     I am a developer by profession
# 5          19                     I am a developer by profession
# 6          23                     I am a developer by profession
# 7          24                     I am a developer by profession
# 8          27                     I am a developer by profession
# 9          29                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  35-44 years old                                Employed, full-time
# 1  45-54 years old                                Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
"LanguageDesireNextYear" in df.columns
# Out:
# False

# %%
df.filter(like="Language").columns
# Out:
# Index(['LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'LanguageAdmired'], dtype='object')

# %%
 

language_usage = (
    df["LanguageHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
)
language_usage
top10 = language_usage.value_counts().head(10)
top10
# Out:
# LanguageHaveWorkedWith
# JavaScript                 14943
# SQL                        12602
# HTML/CSS                   12410
# TypeScript                 10709
# Python                      9590
# Bash/Shell (all shells)     7244
# C#                          6340
# Java                        5982
# PHP                         4644
# PowerShell                  3438
# Name: count, dtype: int64

# %%
language_want = (
    df["LanguageWantToWorkWith"]
    .dropna()
    .str.split(";")
    .explode()
)
language_want
top10 = language_want.value_counts().head(10)
top10
# Out:
# LanguageWantToWorkWith
# JavaScript                 11541
# SQL                        10944
# TypeScript                 10437
# HTML/CSS                   10016
# Python                      8919
# Go                          5661
# Rust                        5597
# C#                          5590
# Bash/Shell (all shells)     5582
# Java                        4048
# Name: count, dtype: int64

# %%
database_have_worked = (
    df["DatabaseHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
)
database_have_worked
top10 = database_have_worked.value_counts().head(10)
top10
# Out:
# DatabaseHaveWorkedWith
# PostgreSQL              11514
# MySQL                    8556
# SQLite                   7021
# MongoDB                  5930
# Microsoft SQL Server     5870
# Redis                    5814
# MariaDB                  3994
# Elasticsearch            3491
# Dynamodb                 2268
# Oracle                   1907
# Name: count, dtype: int64

# %%
database_want_work = (
    df["DatabaseWantToWorkWith"]
    .dropna()
    .str.split(";")
    .explode()
)
database_want_work
top10 = database_want_work.value_counts().head(10)
top10
# Out:
# DatabaseWantToWorkWith
# PostgreSQL              12193
# Redis                    6384
# SQLite                   6295
# MySQL                    6204
# MongoDB                  5618
# Microsoft SQL Server     4345
# Elasticsearch            3665
# MariaDB                  3078
# Dynamodb                 2154
# Supabase                 1623
# Name: count, dtype: int64
