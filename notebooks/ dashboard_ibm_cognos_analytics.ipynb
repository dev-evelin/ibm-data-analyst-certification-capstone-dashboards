# %%
import pandas as pd

# %%
df = pd.read_csv("../data/survey_data_updated.csv")

# %% [markdown]
# ### Current Technology Usage

# %%
#LanguageHaveWorkedWith

language_usage = (
    df["LanguageHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

language_df = pd.DataFrame({
    "LanguageHaveWorkedWith": language_usage
})

language_df.to_csv("LanguageHaveWorkedWith.csv", index=False)
language_df.value_counts()
# Out:
# LanguageHaveWorkedWith
# JavaScript                 14943
# SQL                        12602
# HTML/CSS                   12410
# TypeScript                 10709
# Python                      9590
# Bash/Shell (all shells)     7244
# C#                          6340
# Java                        5982
# PHP                         4644
# PowerShell                  3438
# Go                          3305
# C++                         3081
# C                           2777
# Rust                        2284
# Kotlin                      1958
# Ruby                        1500
# Dart                        1390
# Lua                         1160
# Visual Basic (.Net)          957
# Swift                        898
# Groovy                       756
# R                            711
# VBA                          710
# Assembly                     685
# Elixir                       673
# MATLAB                       592
# Scala                        507
# ...

# %%
import os

os.getcwd()
# Out:
# '/Users/nascimento/developer/repos/learning/ibm-data-analyst-certification-capstone/notebooks'

# %%
#DatabaseHaveWorkedWith

database_usage = (
     df["DatabaseHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

database_df = pd.DataFrame({
    "DatabaseHaveWorkedWith": database_usage
})

database_df = database_df.reset_index(drop=True)

database_df.head()

database_df.to_csv("DatabaseHaveWorkedWith.csv", index=False)

# %%
#PlatformHaveWorkedWith

platform_usage = (
    df["PlatformHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

platform_df = platform_usage.reset_index(drop = True)
platform_df.head(10)

platform_df.to_csv("PlatformHaveWorkedWith.csv", index=False)

# %%
#WebFrameHaveWorkedWith

df["WebframeHaveWorkedWith"]

webframe_usage = (
    df["WebframeHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

webframe_df = webframe_usage.reset_index(drop = True)
webframe_df.head(10)
webframe_df.to_csv("WebframeHaveWorkedWith.csv", index=False)

# %% [markdown]
# ### Future Technology Trend

# %%
#LanguageWantToWorkWith

df["LanguageWantToWorkWith"]

languageWantToWorkWith_usage = (
    df["LanguageWantToWorkWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

languageWantToWorkWith_df = languageWantToWorkWith_usage.reset_index(drop = True)
languageWantToWorkWith_df.head(5)
languageWantToWorkWith_df.to_csv("LanguageWantToWorkWith.csv", index=False)

# %%
#DatabaseWantToWorkWith

df["DatabaseWantToWorkWith"]

databaseWantToWorkWith_usage = (
    df["DatabaseWantToWorkWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

databaseWantToWorkWith_df = databaseWantToWorkWith_usage.reset_index(drop = True)
databaseWantToWorkWith_df.head(5)
databaseWantToWorkWith_df.to_csv("DatabaseWantToWorkWith.csv", index=False)

# %%
#PlatformWantToWorkWith

df["PlatformWantToWorkWith"]

platformWantToWorkWith_usage = (
    df["PlatformWantToWorkWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

platformWantToWorkWith_usage_df = databaseWantToWorkWith_usage.reset_index(drop = True)
platformWantToWorkWith_usage_df.head(5)
platformWantToWorkWith_usage_df.to_csv("PlatformWantToWorkWith.csv", index=False)

# %%
#WebframeWantToWorkWith

df["WebframeWantToWorkWith"]

webframeWantToWorkWith_usage = (
    df["WebframeWantToWorkWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

webframeWantToWorkWith_usage_df = webframeWantToWorkWith_usage.reset_index(drop = True)
webframeWantToWorkWith_usage_df.head(5)
webframeWantToWorkWith_usage_df.to_csv("WebframeWantToWorkWith.csv", index=False)

# %%
#LanguageHaveWorkedWith

language_usage = (
    df["LanguageHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

language_df = pd.DataFrame({
    "LanguageHaveWorkedWith": language_usage
})

language_df.to_csv("LanguageHaveWorkedWith.csv", index=False)
language_df
# Out:
#         LanguageHaveWorkedWith
# 0      Bash/Shell (all shells)
# 0                           Go
# 0                     HTML/CSS
# 0                         Java
# 0                   JavaScript
# ...                        ...
# 18844               PowerShell
# 18844                   Python
# 18844                      SQL
# 18844                    Swift
# 18844               TypeScript
#
# [116557 rows x 1 columns]
